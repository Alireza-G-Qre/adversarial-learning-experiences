# %%
from __future__ import print_function, division
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
import torch.nn as nn
import torch.optim as optim

from torch.optim import lr_scheduler
from torchvision import transforms

import tqdm
import time
import copy
import numpy as np

import torch.nn.functional as F
from torchvision import datasets
from torch.utils.data import DataLoader, ConcatDataset

import warnings
warnings.filterwarnings("ignore")

# %load_ext autotime

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %%
torch.cuda.random.manual_seed(0)
torch.random.manual_seed(0)
np.random.seed(0)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
BATCH_SIZE = 256
EPOCH = 30
LR = 0.01
SAVE_IN = './best_model_wts_v03'

# %% [markdown]
# # Data Preparation

# %%
train_dataset = datasets.MNIST(
        root='data', train=True, download=True,
        transform= transforms.ToTensor())

test_dataset = datasets.MNIST(
        root='data', train=False, download=True,
        transform= transforms.ToTensor())

transformers = transforms.Compose([
        transforms.RandomAffine(degrees = 30),
        transforms.RandomPerspective(),
        transforms.ToTensor()])

train_dataset_transformed = datasets.MNIST(root='data', train=True, download=True, transform=transformers)

# %%
final_dataset = ConcatDataset([train_dataset, train_dataset_transformed])

# %%
test_dataset, valid_subset = torch.utils.data.random_split(
        test_dataset, [5_000, 5_000], generator=torch.Generator())

# %%
train_loader = DataLoader(
        dataset=final_dataset, batch_size=BATCH_SIZE, shuffle=True)

valid_loader = DataLoader(
        dataset=valid_subset, batch_size=BATCH_SIZE, shuffle=False)

test_loader = DataLoader(
        dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
data = next(iter(train_loader))
data[0].shape
# Out:
# torch.Size([256, 1, 28, 28])

# %%
import matplotlib.pyplot as plt

n = 5
fig, axs = plt.subplots(nrows=n, ncols=n, sharex=True, sharey=True, figsize=(12, 12))
for i in range(n ** 2):
    ax = axs[i // n, i % n]
    ax.imshow(data[0][i].squeeze(), cmap=plt.cm.gray)
    ax.set_title(data[1][i])
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
dataloaders_dict = {'train': train_loader, 'val': valid_loader}
dataset_sizes_dict = {'train': len(final_dataset), 'val': len(valid_subset)}

# %% [markdown]
# # Definitions

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(         
            nn.Conv2d(
                in_channels=1,              
                out_channels=16,            
                kernel_size=5,              
                stride=1,                   
                padding=2,                  
            ),                              
            nn.ReLU(),                      
            nn.MaxPool2d(kernel_size=2),    
        )
        self.conv2 = nn.Sequential(         
            nn.Conv2d(16, 32, 5, 1, 2),     
            nn.ReLU(),                      
            nn.MaxPool2d(2),                
        )
        
        self.out = nn.Linear(32 * 7 * 7, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        
        x = x.view(x.size(0), -1)      
        output = self.out(x)
        return output

# %%
class RSAttack:

    def __init__(
            self,
            predict,
            n_queries=5000,
            eps=None,
            p_init=.8,
            n_restarts=1,
            verbose=True,
            targeted=False,
            loss='margin',
            resc_schedule=True,
            device=None,
            constant_schedule=False):

        self.ndims = None
        self.predict = predict
        self.n_queries = n_queries
        self.eps = eps
        self.p_init = p_init
        self.n_restarts = n_restarts
        self.verbose = verbose
        self.targeted = targeted
        self.loss = loss
        self.rescale_schedule = resc_schedule
        self.device = device
        self.constant_schedule = constant_schedule

    def margin_and_loss(self, x, y):

        logits = self.predict(x)

        xent = F.cross_entropy(logits, y, reduction='none')
        u = torch.arange(x.shape[0])
        y_corr = logits[u, y].clone()
        logits[u, y] = -float('inf')
        y_others = logits.max(dim=-1)[0]

        if not self.targeted:
            if self.loss == 'ce':
                return y_corr - y_others, -1. * xent
            elif self.loss == 'margin':
                return y_corr - y_others, y_corr - y_others
        else:
            return y_others - y_corr, xent

    def init_hyperparameters(self, x):

        assert not self.eps is None
        assert self.loss in ['ce', 'margin']

        if self.device is None:
            self.device = x.device

        self.orig_dim = list(x.shape[1:])
        self.ndims = len(self.orig_dim)

        if self.targeted:
            self.loss = 'ce'

    def random_target_classes(self, y_pred, n_classes):
        y = torch.zeros_like(y_pred)
        for counter in range(y_pred.shape[0]):
            l = list(range(n_classes))
            l.remove(y_pred[counter])
            t = self.random_int(0, len(l))
            y[counter] = l[t]

        return y.long().to(self.device)

    def check_shape(self, x):
        return x if len(x.shape) == self.ndims + 1 else x.unsqueeze(0)

    def random_choice(self, shape):
        t = 2 * torch.rand(shape).to(self.device) - 1
        return torch.sign(t)

    def random_int(self, low=0, high=1, shape=None):
        if shape is None:
            shape = [1]

        t = low + (high - low) * torch.rand(shape).to(self.device)
        return t.long()

    def p_selection(self, it):
        """ schedule to decrease the parameter p """

        if self.rescale_schedule:
            it = int(it / self.n_queries * 10000)

        if 0 < it <= 50:
            p = self.p_init / 2
        elif 50 < it <= 200:
            p = self.p_init / 4
        elif 200 < it <= 500:
            p = self.p_init / 5
        elif 500 < it <= 1000:
            p = self.p_init / 6
        elif 1000 < it <= 2000:
            p = self.p_init / 8
        elif 2000 < it <= 4000:
            p = self.p_init / 10
        elif 4000 < it <= 6000:
            p = self.p_init / 12
        elif 6000 < it <= 8000:
            p = self.p_init / 15
        elif 8000 < it:
            p = self.p_init / 20
        else:
            p = self.p_init

        if self.constant_schedule:
            p = self.p_init / 2

        return p

    def attack_single_run(self, x, y):
        with torch.no_grad():

            c, h, w = x.shape[1:]
            n_ex_total = x.shape[0]

            eps = self.eps

            x_best = x.clone()
            n_pixels = h * w
            b_all, be_all = torch.zeros([x.shape[0], eps]).to(self.device).long(), \
                            torch.zeros([x.shape[0], n_pixels - eps]).to(self.device).long()
            for img in range(x.shape[0]):
                ind_all = torch.randperm(n_pixels).to(self.device)
                
                ind_p = ind_all[:eps]
                ind_np = ind_all[eps:]

                x_best[img, :, ind_p // w, ind_p % w] = self.random_choice([c, eps]).clamp(0., 1.)

                b_all[img] = ind_p.clone()
                be_all[img] = ind_np.clone()

            margin_min, loss_min = self.margin_and_loss(x_best, y)
            n_queries = torch.ones(x.shape[0]).to(self.device)

            for it in range(1, self.n_queries):
                # check points still to fool

                idx_to_fool = (margin_min > 0.).nonzero().squeeze()
                x_curr = self.check_shape(x[idx_to_fool])
                x_best_curr = self.check_shape(x_best[idx_to_fool])
                y_curr = y[idx_to_fool]
                margin_min_curr = margin_min[idx_to_fool]
                loss_min_curr = loss_min[idx_to_fool]
                b_curr, be_curr = b_all[idx_to_fool], be_all[idx_to_fool]

                if len(y_curr.shape) == 0:
                    y_curr.unsqueeze_(0)
                    margin_min_curr.unsqueeze_(0)
                    loss_min_curr.unsqueeze_(0)
                    b_curr.unsqueeze_(0)
                    be_curr.unsqueeze_(0)
                    idx_to_fool.unsqueeze_(0)

                # build new candidate
                x_new = x_best_curr.clone()
                eps_it = max(int(self.p_selection(it) * eps), 1)
                ind_p = torch.randperm(eps)[:eps_it]
                ind_np = torch.randperm(n_pixels - eps)[:eps_it]

                for img in range(x_new.shape[0]):
                    p_set = b_curr[img, ind_p]
                    np_set = be_curr[img, ind_np]
                    x_new[img, :, p_set // w, p_set % w] = x_curr[img, :, p_set // w, p_set % w].clone()

                    if eps_it > 1:
                        x_new[img, :, np_set // w, np_set % w] = self.random_choice([c, eps_it]).clamp(0., 1.)
                    else:
                        # if update is 1x1 make sure the sampled color is different from the current one
                        old_clr = x_new[img, :, np_set // w, np_set % w].clone()
                        assert old_clr.shape == (c, 1), print(old_clr)
                        new_clr = old_clr.clone()
                        while (new_clr == old_clr).all().item():
                            new_clr = self.random_choice([c, 1]).clone().clamp(0., 1.)
                        x_new[img, :, np_set // w, np_set % w] = new_clr.clone()

                # compute loss of the new candidates
                margin, loss = self.margin_and_loss(x_new, y_curr)
                n_queries[idx_to_fool] += 1

                # update best solution
                idx_improved = (loss < loss_min_curr).float()
                idx_to_update = (idx_improved > 0.).nonzero().squeeze()
                loss_min[idx_to_fool[idx_to_update]] = loss[idx_to_update]

                idx_miscl = (margin < -1e-6).float()
                idx_improved = torch.max(idx_improved, idx_miscl)
                nimpr = idx_improved.sum().item()
                if nimpr > 0.:
                    idx_improved = (idx_improved.view(-1) > 0).nonzero().squeeze()
                    margin_min[idx_to_fool[idx_improved]] = margin[idx_improved].clone()
                    x_best[idx_to_fool[idx_improved]] = x_new[idx_improved].clone()
                    t = b_curr[idx_improved].clone()
                    te = be_curr[idx_improved].clone()

                    if nimpr > 1:
                        t[:, ind_p] = be_curr[idx_improved][:, ind_np] + 0
                        te[:, ind_np] = b_curr[idx_improved][:, ind_p] + 0
                    else:
                        t[ind_p] = be_curr[idx_improved][ind_np] + 0
                        te[ind_np] = b_curr[idx_improved][ind_p] + 0

                    b_all[idx_to_fool[idx_improved]] = t.clone()
                    be_all[idx_to_fool[idx_improved]] = te.clone()

                # log results current iteration
                ind_succ = (margin_min <= 0.).nonzero().squeeze()
                if self.verbose and ind_succ.numel() != 0:
                    print(' '.join(['{}'.format(it + 1),
                       '- success rate={}/{} ({:.2%})'.format(
                           ind_succ.numel(), n_ex_total,
                           float(ind_succ.numel()) / n_ex_total),
                       '- avg # queries={:.1f}'.format(
                           n_queries[ind_succ].mean().item()),
                       '- med # queries={:.1f}'.format(
                           n_queries[ind_succ].median().item()),
                       '- loss={:.3f}'.format(loss_min.mean()),
                       '- max pert={:.0f}'.format(((x_new - x_curr).abs() > 0).max(1)[0].view(x_new.shape[0], -1).sum(-1).max()),
                       '- epsit={:.0f}'.format(eps_it),
                       ]))

                if ind_succ.numel() == n_ex_total:
                    break

        return n_queries, x_best

    def perturb(self, x, y=None):

        self.init_hyperparameters(x)

        adv = x.clone()
        qr = torch.zeros([x.shape[0]]).to(self.device)

        if y is None:
            if not self.targeted:
                with torch.no_grad():
                    output = self.predict(x)
                    y_pred = output.max(1)[1]
                    y = y_pred.detach().clone().long().to(self.device)
            else:
                with torch.no_grad():
                    output = self.predict(x)
                    n_classes = output.shape[-1]
                    y_pred = output.max(1)[1]
                    y = self.random_target_classes(y_pred, n_classes)
        else:
            y = y.detach().clone().long().to(self.device)

        if not self.targeted:
            acc = self.predict(x).max(1)[1] == y
        else:
            acc = self.predict(x).max(1)[1] != y

        startt = time.time()

        for counter in range(self.n_restarts):
            ind_to_fool = acc.nonzero().squeeze()
            if len(ind_to_fool.shape) == 0:
                ind_to_fool = ind_to_fool.unsqueeze(0)

            if ind_to_fool.numel() != 0:
                x_to_fool = x[ind_to_fool].clone()
                y_to_fool = y[ind_to_fool].clone()

                qr_curr, adv_curr = self.attack_single_run(x_to_fool, y_to_fool)

                output_curr = self.predict(adv_curr)
                if not self.targeted:
                    acc_curr = output_curr.max(1)[1] == y_to_fool
                else:
                    acc_curr = output_curr.max(1)[1] != y_to_fool
                ind_curr = (acc_curr == 0).nonzero().squeeze()

                acc[ind_to_fool[ind_curr]] = 0
                adv[ind_to_fool[ind_curr]] = adv_curr[ind_curr].clone()
                qr[ind_to_fool[ind_curr]] = qr_curr[ind_curr].clone()

                if self.verbose:
                    print('restart {} - robust accuracy: {:.2%}'.format(
                        counter, acc.float().mean()),
                        '- cum. time: {:.1f} s'.format(
                            time.time() - startt))

        return qr, adv

# %%
def train_model(model, criterion, optimizer, scheduler, attack, dataloaders, dataset_sizes, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    nqs = []

    for epoch in range(num_epochs):
        for phase in ['train', 'val']:

            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in tqdm.tqdm(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)

                if attack and phase == 'train':
                    nq, inputs = attack(inputs, labels)
                    nqs.append(nq.nonzero().shape[0])

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):

                    outputs = model(inputs)
                    _, predictions = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(predictions == labels.data)

            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('epoch:{} phase:{}'.format(epoch + 1, phase))
            print(
                '{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                torch.save(best_model_wts, SAVE_IN)

    time_elapsed = time.time() - since

    print(
        'Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print(
        'Best val Acc: {:4f}'.format(best_acc))
    print(
        'Mean qs: {:4f}'.format(sum(nqs) / len(nqs)))

    model.load_state_dict(best_model_wts)

    return model

# %% [markdown]
# <hr>

# %%
net = CNN().to(device)

# %%
criterion_md, optimizer_md = \
    nn.CrossEntropyLoss(), optim.Adam(net.parameters(), lr=LR)

lr_scheduler_md = lr_scheduler.StepLR(optimizer_md, step_size=10, gamma=0.1)

# %%
adversary = RSAttack(net, eps=10, verbose=False, n_queries=1_000, loss='ce', device=device)

# %%
# train normal
_ = train_model(
        net, criterion_md, optimizer_md, lr_scheduler_md, adversary.perturb,
        dataloaders_dict, dataset_sizes_dict, num_epochs=EPOCH)
# Out:
#  78%|███████▊  | 367/469 [7:54:10<125:39:53, 4435.23s/it]

# %% [markdown]
# # Prediction

# %%
def predict(classifier, dataloader):

    test_pred = torch.LongTensor()
    classifier.eval()

    with torch.no_grad():

        for images in dataloader:

            images = torch.autograd.Variable(images[0])
            if torch.cuda.is_available():
                images = images.to(device)

            outputs = classifier(images)
            predicted = outputs.cpu().data.max(1, keepdim=True)[1]
            test_pred = torch.cat((test_pred, predicted), dim=0)

    return test_pred

# %%
net = CNN().to(device)
net.load_state_dict(torch.load(SAVE_IN))
# Out:
# <All keys matched successfully>

# %%
results = predict(net, test_loader)

# %%
import matplotlib.pyplot as plt

n = 5
fig, axs = plt.subplots(nrows=n, ncols=n, sharex=True, sharey=True, figsize=(12, 12))
for i in range(n ** 2):
    ax = axs[i // n, i % n]
    ax.imshow(test_dataset[i][0][0], cmap=plt.cm.gray)
    ax.set_title(results[i])
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
adversary = RSAttack(net, eps=10, verbose=True, n_queries=700, loss='ce', device=device)

# %%
data = next(iter(train_loader))
data[0].shape
# Out:
# torch.Size([256, 1, 28, 28])

# %%
# %%time
qs, adv_examples = adversary.perturb(
    data[0].to(device), data[1].to(device))
# Out:
# 2 - success rate=9/249 (3.61%) - avg # queries=1.4 - med # queries=1.0 - loss=-0.124 - max pert=10 - epsit=4
# 3 - success rate=12/249 (4.82%) - avg # queries=1.8 - med # queries=2.0 - loss=-0.150 - max pert=10 - epsit=4
# 4 - success rate=17/249 (6.83%) - avg # queries=2.5 - med # queries=2.0 - loss=-0.183 - max pert=10 - epsit=4
# 5 - success rate=19/249 (7.63%) - avg # queries=2.7 - med # queries=3.0 - loss=-0.198 - max pert=10 - epsit=2
# 6 - success rate=22/249 (8.84%) - avg # queries=3.2 - med # queries=3.0 - loss=-0.215 - max pert=10 - epsit=2
# 7 - success rate=27/249 (10.84%) - avg # queries=3.9 - med # queries=4.0 - loss=-0.240 - max pert=10 - epsit=2
# 8 - success rate=30/249 (12.05%) - avg # queries=4.3 - med # queries=4.0 - loss=-0.262 - max pert=10 - epsit=2
# 9 - success rate=33/249 (13.25%) - avg # queries=4.7 - med # queries=4.0 - loss=-0.272 - max pert=9 - epsit=2
# 10 - success rate=36/249 (14.46%) - avg # queries=5.2 - med # queries=5.0 - loss=-0.290 - max pert=10 - epsit=2
# 11 - success rate=39/249 (15.66%) - avg # queries=5.6 - med # queries=6.0 - loss=-0.297 - max pert=9 - epsit=2
# 12 - success rate=41/249 (16.47%) - avg # queries=5.9 - med # queries=6.0 - loss=-0.320 - max pert=10 - epsit=2
# 13 - success rate=44/249 (17.67%) - avg # queries=6.4 - med # queries=6.0 - loss=-0.331 - max pert=10 - epsit=2
# 14 - success rate=47/249 (18.88%) - avg # queries=6.9 - med # queries=7.0 - loss=-0.341 - max pert=10 - epsit=2
# 15 - success rate=48/249 (19.28%) - avg # queries=7.1 - med # queries=7.0 - loss=-0.352 - max pert=10 - epsit=2
# 16 - success rate=52/249 (20.88%) - avg # queries=7.8 - med # queries=7.0 - loss=-0.370 - max pert=10 - epsit=1
# 17 - success rate=56/249 (22.49%) - avg # queries=8.4 - med # queries=8.0 - loss=-0.385 - max pert=10 - epsit=1
# 18 - success rate=62/249 (24.90%) - avg # queries=9.3 - med # queries=9.0 - loss=-0.410 - max pert=10 - epsit=1
# 19 - success rate=71/249 (28.51%) - avg # queries=10.6 - med # queries=10.0 - loss=-0.445 - max pert=10 - epsit=1
# 20 - success rate=73/249 (29.32%) - avg # queries=10.8 - med # queries=11.0 - loss=-0.456 - max pert=10 - epsit=1
# 21 - success rate=77/249 (30.92%) - avg # queries=11.4 - med # queries=11.0 - loss=-0.476 - max pert=10 - epsit=1
# 22 - success rate=78/249 (31.33%) - avg # queries=11.5 - med # queries=11.0 - loss=-0.478 - max pert=10 - epsit=1
# 23 - success rate=82/249 (32.93%) - avg # queries=12.0 - med # queries=12.0 - loss=-0.494 - max pert=10 - epsit=1
# 24 - success rate=83/249 (33.33%) - avg # queries=12.2 - med # queries=13.0 - loss=-0.506 - max pert=10 - epsit=1
# 25 - success rate=87/249 (34.94%) - avg # queries=12.8 - med # queries=13.0 - loss=-0.525 - max pert=10 - epsit=1
# 26 - success rate=91/249 (36.55%) - avg # queries=13.4 - med # queries=14.0 - loss=-0.540 - max pert=10 - epsit=1
# 27 - success rate=94/249 (37.75%) - avg # queries=13.8 - med # queries=14.0 - loss=-0.547 - max pert=10 - epsit=1
# 28 - success rate=96/249 (38.55%) - avg # queries=14.1 - med # queries=15.0 - loss=-0.558 - max pert=10 - epsit=1
# 29 - success rate=97/249 (38.96%) - avg # queries=14.2 - med # queries=16.0 - loss=-0.569 - max pert=10 - epsit=1
# 30 - success rate=100/249 (40.16%) - avg # queries=14.7 - med # queries=16.0 - loss=-0.583 - max pert=10 - epsit=1
# 31 - success rate=106/249 (42.57%) - avg # queries=15.6 - med # queries=17.0 - loss=-0.603 - max pert=10 - epsit=1
# 32 - success rate=108/249 (43.37%) - avg # queries=15.9 - med # queries=17.0 - loss=-0.606 - max pert=10 - epsit=1
# 33 - success rate=110/249 (44.18%) - avg # queries=16.3 - med # queries=17.0 - loss=-0.620 - max pert=10 - epsit=1
# 34 - success rate=112/249 (44.98%) - avg # queries=16.6 - med # queries=17.0 - loss=-0.629 - max pert=10 - epsit=1
# 35 - success rate=113/249 (45.38%) - avg # queries=16.7 - med # queries=18.0 - loss=-0.632 - max pert=10 - epsit=1
# 36 - success rate=115/249 (46.18%) - avg # queries=17.1 - med # queries=18.0 - loss=-0.640 - max pert=10 - epsit=1
# 37 - success rate=117/249 (46.99%) - avg # queries=17.4 - med # queries=18.0 - loss=-0.646 - max pert=10 - epsit=1
# 38 - success rate=119/249 (47.79%) - avg # queries=17.8 - med # queries=18.0 - loss=-0.653 - max pert=10 - epsit=1
# 39 - success rate=124/249 (49.80%) - avg # queries=18.6 - med # queries=18.0 - loss=-0.664 - max pert=10 - epsit=1
# 40 - success rate=126/249 (50.60%) - avg # queries=19.0 - med # queries=19.0 - loss=-0.673 - max pert=10 - epsit=1
# 41 - success rate=127/249 (51.00%) - avg # queries=19.1 - med # queries=19.0 - loss=-0.676 - max pert=10 - epsit=1
# 42 - success rate=127/249 (51.00%) - avg # queries=19.1 - med # queries=19.0 - loss=-0.678 - max pert=10 - epsit=1
# 43 - success rate=128/249 (51.41%) - avg # queries=19.3 - med # queries=19.0 - loss=-0.686 - max pert=10 - epsit=1
# 44 - success rate=128/249 (51.41%) - avg # queries=19.3 - med # queries=19.0 - loss=-0.688 - max pert=10 - epsit=1
# 45 - success rate=129/249 (51.81%) - avg # queries=19.5 - med # queries=19.0 - loss=-0.692 - max pert=10 - epsit=1
# 46 - success rate=132/249 (53.01%) - avg # queries=20.1 - med # queries=19.0 - loss=-0.701 - max pert=10 - epsit=1
# 47 - success rate=133/249 (53.41%) - avg # queries=20.3 - med # queries=19.0 - loss=-0.707 - max pert=10 - epsit=1
# 48 - success rate=135/249 (54.22%) - avg # queries=20.7 - med # queries=19.0 - loss=-0.720 - max pert=10 - epsit=1
# 49 - success rate=136/249 (54.62%) - avg # queries=20.9 - med # queries=19.0 - loss=-0.727 - max pert=10 - epsit=1
# 50 - success rate=137/249 (55.02%) - avg # queries=21.1 - med # queries=19.0 - loss=-0.728 - max pert=10 - epsit=1
# 51 - success rate=138/249 (55.42%) - avg # queries=21.4 - med # queries=19.0 - loss=-0.734 - max pert=10 - epsit=1
# 52 - success rate=142/249 (57.03%) - avg # queries=22.2 - med # queries=19.0 - loss=-0.749 - max pert=10 - epsit=1
# 53 - success rate=143/249 (57.43%) - avg # queries=22.4 - med # queries=20.0 - loss=-0.754 - max pert=10 - epsit=1
# 54 - success rate=146/249 (58.63%) - avg # queries=23.1 - med # queries=20.0 - loss=-0.760 - max pert=10 - epsit=1
# 55 - success rate=147/249 (59.04%) - avg # queries=23.3 - med # queries=21.0 - loss=-0.765 - max pert=10 - epsit=1
# 56 - success rate=148/249 (59.44%) - avg # queries=23.5 - med # queries=21.0 - loss=-0.771 - max pert=10 - epsit=1
# 57 - success rate=149/249 (59.84%) - avg # queries=23.8 - med # queries=21.0 - loss=-0.775 - max pert=10 - epsit=1
# 58 - success rate=152/249 (61.04%) - avg # queries=24.4 - med # queries=21.0 - loss=-0.780 - max pert=10 - epsit=1
# 59 - success rate=154/249 (61.85%) - avg # queries=24.9 - med # queries=21.0 - loss=-0.788 - max pert=10 - epsit=1
# 60 - success rate=155/249 (62.25%) - avg # queries=25.1 - med # queries=22.0 - loss=-0.789 - max pert=10 - epsit=1
# 61 - success rate=157/249 (63.05%) - avg # queries=25.6 - med # queries=23.0 - loss=-0.795 - max pert=10 - epsit=1
# 62 - success rate=158/249 (63.45%) - avg # queries=25.8 - med # queries=23.0 - loss=-0.800 - max pert=10 - epsit=1
# 63 - success rate=159/249 (63.86%) - avg # queries=26.0 - med # queries=23.0 - loss=-0.801 - max pert=10 - epsit=1
# 64 - success rate=159/249 (63.86%) - avg # queries=26.0 - med # queries=23.0 - loss=-0.806 - max pert=10 - epsit=1
# 65 - success rate=160/249 (64.26%) - avg # queries=26.3 - med # queries=23.0 - loss=-0.811 - max pert=10 - epsit=1
# 66 - success rate=162/249 (65.06%) - avg # queries=26.8 - med # queries=23.0 - loss=-0.819 - max pert=10 - epsit=1
# 67 - success rate=164/249 (65.86%) - avg # queries=27.2 - med # queries=23.0 - loss=-0.823 - max pert=10 - epsit=1
# 68 - success rate=164/249 (65.86%) - avg # queries=27.2 - med # queries=23.0 - loss=-0.825 - max pert=10 - epsit=1
# 69 - success rate=165/249 (66.27%) - avg # queries=27.5 - med # queries=24.0 - loss=-0.829 - max pert=10 - epsit=1
# 70 - success rate=165/249 (66.27%) - avg # queries=27.5 - med # queries=24.0 - loss=-0.830 - max pert=10 - epsit=1
# 71 - success rate=166/249 (66.67%) - avg # queries=27.8 - med # queries=24.0 - loss=-0.834 - max pert=10 - epsit=1
# 72 - success rate=167/249 (67.07%) - avg # queries=28.0 - med # queries=25.0 - loss=-0.840 - max pert=10 - epsit=1
# 73 - success rate=167/249 (67.07%) - avg # queries=28.0 - med # queries=25.0 - loss=-0.843 - max pert=10 - epsit=1
# 74 - success rate=167/249 (67.07%) - avg # queries=28.0 - med # queries=25.0 - loss=-0.844 - max pert=10 - epsit=1
# 75 - success rate=167/249 (67.07%) - avg # queries=28.0 - med # queries=25.0 - loss=-0.845 - max pert=10 - epsit=1
# 76 - success rate=170/249 (68.27%) - avg # queries=28.9 - med # queries=25.0 - loss=-0.851 - max pert=10 - epsit=1
# 77 - success rate=170/249 (68.27%) - avg # queries=28.9 - med # queries=25.0 - loss=-0.854 - max pert=10 - epsit=1
# 78 - success rate=171/249 (68.67%) - avg # queries=29.2 - med # queries=25.0 - loss=-0.857 - max pert=10 - epsit=1
# 79 - success rate=171/249 (68.67%) - avg # queries=29.2 - med # queries=25.0 - loss=-0.858 - max pert=10 - epsit=1
# 80 - success rate=172/249 (69.08%) - avg # queries=29.5 - med # queries=25.0 - loss=-0.865 - max pert=10 - epsit=1
# 81 - success rate=173/249 (69.48%) - avg # queries=29.8 - med # queries=25.0 - loss=-0.867 - max pert=10 - epsit=1
# 82 - success rate=173/249 (69.48%) - avg # queries=29.8 - med # queries=25.0 - loss=-0.870 - max pert=10 - epsit=1
# 83 - success rate=175/249 (70.28%) - avg # queries=30.4 - med # queries=26.0 - loss=-0.874 - max pert=10 - epsit=1
# 84 - success rate=176/249 (70.68%) - avg # queries=30.7 - med # queries=26.0 - loss=-0.877 - max pert=10 - epsit=1
# 85 - success rate=177/249 (71.08%) - avg # queries=31.0 - med # queries=26.0 - loss=-0.881 - max pert=10 - epsit=1
# 86 - success rate=177/249 (71.08%) - avg # queries=31.0 - med # queries=26.0 - loss=-0.881 - max pert=10 - epsit=1
# 87 - success rate=177/249 (71.08%) - avg # queries=31.0 - med # queries=26.0 - loss=-0.882 - max pert=10 - epsit=1
# 88 - success rate=178/249 (71.49%) - avg # queries=31.3 - med # queries=26.0 - loss=-0.884 - max pert=10 - epsit=1
# 89 - success rate=178/249 (71.49%) - avg # queries=31.3 - med # queries=26.0 - loss=-0.886 - max pert=10 - epsit=1
# 90 - success rate=179/249 (71.89%) - avg # queries=31.6 - med # queries=26.0 - loss=-0.889 - max pert=10 - epsit=1
# 91 - success rate=180/249 (72.29%) - avg # queries=32.0 - med # queries=26.0 - loss=-0.894 - max pert=10 - epsit=1
# 92 - success rate=181/249 (72.69%) - avg # queries=32.3 - med # queries=26.0 - loss=-0.901 - max pert=10 - epsit=1
# 93 - success rate=181/249 (72.69%) - avg # queries=32.3 - med # queries=26.0 - loss=-0.902 - max pert=10 - epsit=1
# 94 - success rate=181/249 (72.69%) - avg # queries=32.3 - med # queries=26.0 - loss=-0.903 - max pert=10 - epsit=1
# 95 - success rate=181/249 (72.69%) - avg # queries=32.3 - med # queries=26.0 - loss=-0.906 - max pert=10 - epsit=1
# 96 - success rate=182/249 (73.09%) - avg # queries=32.6 - med # queries=26.0 - loss=-0.910 - max pert=10 - epsit=1
# 97 - success rate=183/249 (73.49%) - avg # queries=33.0 - med # queries=27.0 - loss=-0.911 - max pert=10 - epsit=1
# 98 - success rate=183/249 (73.49%) - avg # queries=33.0 - med # queries=27.0 - loss=-0.912 - max pert=10 - epsit=1
# 99 - success rate=187/249 (75.10%) - avg # queries=34.4 - med # queries=27.0 - loss=-0.920 - max pert=10 - epsit=1
# 100 - success rate=188/249 (75.50%) - avg # queries=34.8 - med # queries=27.0 - loss=-0.922 - max pert=10 - epsit=1
# 101 - success rate=188/249 (75.50%) - avg # queries=34.8 - med # queries=27.0 - loss=-0.922 - max pert=10 - epsit=1
# 102 - success rate=188/249 (75.50%) - avg # queries=34.8 - med # queries=27.0 - loss=-0.923 - max pert=10 - epsit=1
# 103 - success rate=188/249 (75.50%) - avg # queries=34.8 - med # queries=27.0 - loss=-0.924 - max pert=10 - epsit=1
# 104 - success rate=189/249 (75.90%) - avg # queries=35.1 - med # queries=28.0 - loss=-0.925 - max pert=10 - epsit=1
# 105 - success rate=189/249 (75.90%) - avg # queries=35.1 - med # queries=28.0 - loss=-0.925 - max pert=10 - epsit=1
# 106 - success rate=189/249 (75.90%) - avg # queries=35.1 - med # queries=28.0 - loss=-0.926 - max pert=10 - epsit=1
# 107 - success rate=189/249 (75.90%) - avg # queries=35.1 - med # queries=28.0 - loss=-0.926 - max pert=10 - epsit=1
# 108 - success rate=190/249 (76.31%) - avg # queries=35.5 - med # queries=28.0 - loss=-0.927 - max pert=10 - epsit=1
# 109 - success rate=191/249 (76.71%) - avg # queries=35.9 - med # queries=28.0 - loss=-0.927 - max pert=10 - epsit=1
# 110 - success rate=192/249 (77.11%) - avg # queries=36.3 - med # queries=28.0 - loss=-0.932 - max pert=10 - epsit=1
# 111 - success rate=193/249 (77.51%) - avg # queries=36.7 - med # queries=29.0 - loss=-0.934 - max pert=10 - epsit=1
# 112 - success rate=193/249 (77.51%) - avg # queries=36.7 - med # queries=29.0 - loss=-0.934 - max pert=10 - epsit=1
# 113 - success rate=193/249 (77.51%) - avg # queries=36.7 - med # queries=29.0 - loss=-0.937 - max pert=10 - epsit=1
# 114 - success rate=194/249 (77.91%) - avg # queries=37.1 - med # queries=29.0 - loss=-0.938 - max pert=10 - epsit=1
# 115 - success rate=194/249 (77.91%) - avg # queries=37.1 - med # queries=29.0 - loss=-0.939 - max pert=10 - epsit=1
# 116 - success rate=194/249 (77.91%) - avg # queries=37.1 - med # queries=29.0 - loss=-0.939 - max pert=10 - epsit=1
# 117 - success rate=196/249 (78.71%) - avg # queries=37.9 - med # queries=30.0 - loss=-0.943 - max pert=10 - epsit=1
# 118 - success rate=196/249 (78.71%) - avg # queries=37.9 - med # queries=30.0 - loss=-0.944 - max pert=10 - epsit=1
# 119 - success rate=196/249 (78.71%) - avg # queries=37.9 - med # queries=30.0 - loss=-0.946 - max pert=10 - epsit=1
# 120 - success rate=197/249 (79.12%) - avg # queries=38.3 - med # queries=30.0 - loss=-0.949 - max pert=10 - epsit=1
# 121 - success rate=198/249 (79.52%) - avg # queries=38.7 - med # queries=30.0 - loss=-0.951 - max pert=10 - epsit=1
# 122 - success rate=199/249 (79.92%) - avg # queries=39.1 - med # queries=30.0 - loss=-0.953 - max pert=10 - epsit=1
# 123 - success rate=199/249 (79.92%) - avg # queries=39.1 - med # queries=30.0 - loss=-0.953 - max pert=10 - epsit=1
# 124 - success rate=200/249 (80.32%) - avg # queries=39.5 - med # queries=30.0 - loss=-0.954 - max pert=10 - epsit=1
# 125 - success rate=200/249 (80.32%) - avg # queries=39.5 - med # queries=30.0 - loss=-0.954 - max pert=10 - epsit=1
# 126 - success rate=200/249 (80.32%) - avg # queries=39.5 - med # queries=30.0 - loss=-0.956 - max pert=10 - epsit=1
# 127 - success rate=200/249 (80.32%) - avg # queries=39.5 - med # queries=30.0 - loss=-0.956 - max pert=10 - epsit=1
# 128 - success rate=201/249 (80.72%) - avg # queries=40.0 - med # queries=31.0 - loss=-0.960 - max pert=10 - epsit=1
# 129 - success rate=201/249 (80.72%) - avg # queries=40.0 - med # queries=31.0 - loss=-0.961 - max pert=10 - epsit=1
# 130 - success rate=202/249 (81.12%) - avg # queries=40.4 - med # queries=31.0 - loss=-0.961 - max pert=10 - epsit=1
# 131 - success rate=203/249 (81.53%) - avg # queries=40.9 - med # queries=31.0 - loss=-0.963 - max pert=10 - epsit=1
# 132 - success rate=203/249 (81.53%) - avg # queries=40.9 - med # queries=31.0 - loss=-0.963 - max pert=10 - epsit=1
# 133 - success rate=203/249 (81.53%) - avg # queries=40.9 - med # queries=31.0 - loss=-0.964 - max pert=10 - epsit=1
# 134 - success rate=203/249 (81.53%) - avg # queries=40.9 - med # queries=31.0 - loss=-0.965 - max pert=10 - epsit=1
# 135 - success rate=204/249 (81.93%) - avg # queries=41.3 - med # queries=31.0 - loss=-0.968 - max pert=10 - epsit=1
# 136 - success rate=204/249 (81.93%) - avg # queries=41.3 - med # queries=31.0 - loss=-0.968 - max pert=10 - epsit=1
# 137 - success rate=205/249 (82.33%) - avg # queries=41.8 - med # queries=31.0 - loss=-0.969 - max pert=10 - epsit=1
# 138 - success rate=205/249 (82.33%) - avg # queries=41.8 - med # queries=31.0 - loss=-0.969 - max pert=10 - epsit=1
# 139 - success rate=206/249 (82.73%) - avg # queries=42.3 - med # queries=31.0 - loss=-0.970 - max pert=10 - epsit=1
# 140 - success rate=206/249 (82.73%) - avg # queries=42.3 - med # queries=31.0 - loss=-0.971 - max pert=10 - epsit=1
# 141 - success rate=206/249 (82.73%) - avg # queries=42.3 - med # queries=31.0 - loss=-0.971 - max pert=10 - epsit=1
# 142 - success rate=207/249 (83.13%) - avg # queries=42.8 - med # queries=31.0 - loss=-0.973 - max pert=10 - epsit=1
# 143 - success rate=207/249 (83.13%) - avg # queries=42.8 - med # queries=31.0 - loss=-0.973 - max pert=10 - epsit=1
# 144 - success rate=210/249 (84.34%) - avg # queries=44.2 - med # queries=31.0 - loss=-0.977 - max pert=10 - epsit=1
# 145 - success rate=210/249 (84.34%) - avg # queries=44.2 - med # queries=31.0 - loss=-0.978 - max pert=10 - epsit=1
# 146 - success rate=210/249 (84.34%) - avg # queries=44.2 - med # queries=31.0 - loss=-0.978 - max pert=10 - epsit=1
# 147 - success rate=210/249 (84.34%) - avg # queries=44.2 - med # queries=31.0 - loss=-0.979 - max pert=10 - epsit=1
# 148 - success rate=210/249 (84.34%) - avg # queries=44.2 - med # queries=31.0 - loss=-0.979 - max pert=10 - epsit=1
# 149 - success rate=210/249 (84.34%) - avg # queries=44.2 - med # queries=31.0 - loss=-0.980 - max pert=10 - epsit=1
# 150 - success rate=211/249 (84.74%) - avg # queries=44.7 - med # queries=31.0 - loss=-0.981 - max pert=10 - epsit=1
# 151 - success rate=211/249 (84.74%) - avg # queries=44.7 - med # queries=31.0 - loss=-0.982 - max pert=10 - epsit=1
# 152 - success rate=211/249 (84.74%) - avg # queries=44.7 - med # queries=31.0 - loss=-0.983 - max pert=10 - epsit=1
# 153 - success rate=211/249 (84.74%) - avg # queries=44.7 - med # queries=31.0 - loss=-0.983 - max pert=10 - epsit=1
# 154 - success rate=212/249 (85.14%) - avg # queries=45.2 - med # queries=31.0 - loss=-0.984 - max pert=10 - epsit=1
# 155 - success rate=213/249 (85.54%) - avg # queries=45.7 - med # queries=32.0 - loss=-0.985 - max pert=10 - epsit=1
# 156 - success rate=213/249 (85.54%) - avg # queries=45.7 - med # queries=32.0 - loss=-0.986 - max pert=10 - epsit=1
# 157 - success rate=213/249 (85.54%) - avg # queries=45.7 - med # queries=32.0 - loss=-0.986 - max pert=10 - epsit=1
# 158 - success rate=213/249 (85.54%) - avg # queries=45.7 - med # queries=32.0 - loss=-0.986 - max pert=10 - epsit=1
# 159 - success rate=214/249 (85.94%) - avg # queries=46.3 - med # queries=32.0 - loss=-0.987 - max pert=10 - epsit=1
# 160 - success rate=214/249 (85.94%) - avg # queries=46.3 - med # queries=32.0 - loss=-0.987 - max pert=10 - epsit=1
# 161 - success rate=214/249 (85.94%) - avg # queries=46.3 - med # queries=32.0 - loss=-0.987 - max pert=10 - epsit=1
# 162 - success rate=214/249 (85.94%) - avg # queries=46.3 - med # queries=32.0 - loss=-0.987 - max pert=10 - epsit=1
# 163 - success rate=215/249 (86.35%) - avg # queries=46.8 - med # queries=32.0 - loss=-0.988 - max pert=10 - epsit=1
# 164 - success rate=216/249 (86.75%) - avg # queries=47.4 - med # queries=32.0 - loss=-0.989 - max pert=10 - epsit=1
# 165 - success rate=216/249 (86.75%) - avg # queries=47.4 - med # queries=32.0 - loss=-0.990 - max pert=10 - epsit=1
# 166 - success rate=218/249 (87.55%) - avg # queries=48.4 - med # queries=33.0 - loss=-0.994 - max pert=10 - epsit=1
# 167 - success rate=218/249 (87.55%) - avg # queries=48.4 - med # queries=33.0 - loss=-0.995 - max pert=10 - epsit=1
# 168 - success rate=218/249 (87.55%) - avg # queries=48.4 - med # queries=33.0 - loss=-0.995 - max pert=10 - epsit=1
# 169 - success rate=218/249 (87.55%) - avg # queries=48.4 - med # queries=33.0 - loss=-0.996 - max pert=10 - epsit=1
# 170 - success rate=219/249 (87.95%) - avg # queries=49.0 - med # queries=33.0 - loss=-0.997 - max pert=10 - epsit=1
# 171 - success rate=219/249 (87.95%) - avg # queries=49.0 - med # queries=33.0 - loss=-0.997 - max pert=10 - epsit=1
# 172 - success rate=219/249 (87.95%) - avg # queries=49.0 - med # queries=33.0 - loss=-0.997 - max pert=10 - epsit=1
# 173 - success rate=219/249 (87.95%) - avg # queries=49.0 - med # queries=33.0 - loss=-0.997 - max pert=10 - epsit=1
# 174 - success rate=219/249 (87.95%) - avg # queries=49.0 - med # queries=33.0 - loss=-0.997 - max pert=10 - epsit=1
# 175 - success rate=219/249 (87.95%) - avg # queries=49.0 - med # queries=33.0 - loss=-0.999 - max pert=10 - epsit=1
# 176 - success rate=219/249 (87.95%) - avg # queries=49.0 - med # queries=33.0 - loss=-0.999 - max pert=10 - epsit=1
# 177 - success rate=219/249 (87.95%) - avg # queries=49.0 - med # queries=33.0 - loss=-0.999 - max pert=10 - epsit=1
# 178 - success rate=219/249 (87.95%) - avg # queries=49.0 - med # queries=33.0 - loss=-1.000 - max pert=10 - epsit=1
# 179 - success rate=219/249 (87.95%) - avg # queries=49.0 - med # queries=33.0 - loss=-1.000 - max pert=10 - epsit=1
# 180 - success rate=221/249 (88.76%) - avg # queries=50.2 - med # queries=34.0 - loss=-1.003 - max pert=10 - epsit=1
# 181 - success rate=221/249 (88.76%) - avg # queries=50.2 - med # queries=34.0 - loss=-1.003 - max pert=10 - epsit=1
# 182 - success rate=221/249 (88.76%) - avg # queries=50.2 - med # queries=34.0 - loss=-1.003 - max pert=10 - epsit=1
# 183 - success rate=221/249 (88.76%) - avg # queries=50.2 - med # queries=34.0 - loss=-1.004 - max pert=10 - epsit=1
# 184 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.006 - max pert=10 - epsit=1
# 185 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.006 - max pert=10 - epsit=1
# 186 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.007 - max pert=10 - epsit=1
# 187 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.007 - max pert=10 - epsit=1
# 188 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.007 - max pert=10 - epsit=1
# 189 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.007 - max pert=10 - epsit=1
# 190 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.007 - max pert=10 - epsit=1
# 191 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.008 - max pert=10 - epsit=1
# 192 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.008 - max pert=10 - epsit=1
# 193 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.008 - max pert=10 - epsit=1
# 194 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.008 - max pert=10 - epsit=1
# 195 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.008 - max pert=10 - epsit=1
# 196 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.009 - max pert=10 - epsit=1
# 197 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.009 - max pert=10 - epsit=1
# 198 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.009 - max pert=10 - epsit=1
# 199 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.009 - max pert=10 - epsit=1
# 200 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.009 - max pert=10 - epsit=1
# 201 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.009 - max pert=10 - epsit=1
# 202 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.009 - max pert=10 - epsit=1
# 203 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.009 - max pert=10 - epsit=1
# 204 - success rate=222/249 (89.16%) - avg # queries=50.8 - med # queries=34.0 - loss=-1.009 - max pert=10 - epsit=1
# 205 - success rate=223/249 (89.56%) - avg # queries=51.5 - med # queries=34.0 - loss=-1.011 - max pert=10 - epsit=1
# 206 - success rate=224/249 (89.96%) - avg # queries=52.2 - med # queries=34.0 - loss=-1.011 - max pert=10 - epsit=1
# 207 - success rate=225/249 (90.36%) - avg # queries=52.9 - med # queries=35.0 - loss=-1.012 - max pert=10 - epsit=1
# 208 - success rate=225/249 (90.36%) - avg # queries=52.9 - med # queries=35.0 - loss=-1.012 - max pert=10 - epsit=1
# 209 - success rate=225/249 (90.36%) - avg # queries=52.9 - med # queries=35.0 - loss=-1.012 - max pert=10 - epsit=1
# 210 - success rate=225/249 (90.36%) - avg # queries=52.9 - med # queries=35.0 - loss=-1.012 - max pert=10 - epsit=1
# 211 - success rate=225/249 (90.36%) - avg # queries=52.9 - med # queries=35.0 - loss=-1.012 - max pert=10 - epsit=1
# 212 - success rate=225/249 (90.36%) - avg # queries=52.9 - med # queries=35.0 - loss=-1.012 - max pert=10 - epsit=1
# 213 - success rate=225/249 (90.36%) - avg # queries=52.9 - med # queries=35.0 - loss=-1.012 - max pert=10 - epsit=1
# 214 - success rate=225/249 (90.36%) - avg # queries=52.9 - med # queries=35.0 - loss=-1.012 - max pert=10 - epsit=1
# 215 - success rate=225/249 (90.36%) - avg # queries=52.9 - med # queries=35.0 - loss=-1.012 - max pert=10 - epsit=1
# 216 - success rate=225/249 (90.36%) - avg # queries=52.9 - med # queries=35.0 - loss=-1.012 - max pert=10 - epsit=1
# 217 - success rate=225/249 (90.36%) - avg # queries=52.9 - med # queries=35.0 - loss=-1.012 - max pert=10 - epsit=1
# 218 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.013 - max pert=10 - epsit=1
# 219 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.013 - max pert=10 - epsit=1
# 220 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.014 - max pert=10 - epsit=1
# 221 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.014 - max pert=10 - epsit=1
# 222 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.014 - max pert=10 - epsit=1
# 223 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.014 - max pert=10 - epsit=1
# 224 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.014 - max pert=10 - epsit=1
# 225 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.014 - max pert=10 - epsit=1
# 226 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.014 - max pert=10 - epsit=1
# 227 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.015 - max pert=10 - epsit=1
# 228 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.015 - max pert=10 - epsit=1
# 229 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.015 - max pert=10 - epsit=1
# 230 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.015 - max pert=10 - epsit=1
# 231 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.015 - max pert=10 - epsit=1
# 232 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.015 - max pert=10 - epsit=1
# 233 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.015 - max pert=10 - epsit=1
# 234 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.015 - max pert=10 - epsit=1
# 235 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.015 - max pert=10 - epsit=1
# 236 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.015 - max pert=10 - epsit=1
# 237 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.016 - max pert=10 - epsit=1
# 238 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.016 - max pert=10 - epsit=1
# 239 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.016 - max pert=10 - epsit=1
# 240 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.016 - max pert=10 - epsit=1
# 241 - success rate=227/249 (91.16%) - avg # queries=54.3 - med # queries=36.0 - loss=-1.016 - max pert=10 - epsit=1
# 242 - success rate=228/249 (91.57%) - avg # queries=55.1 - med # queries=36.0 - loss=-1.022 - max pert=10 - epsit=1
# 243 - success rate=228/249 (91.57%) - avg # queries=55.1 - med # queries=36.0 - loss=-1.022 - max pert=10 - epsit=1
# 244 - success rate=229/249 (91.97%) - avg # queries=56.0 - med # queries=36.0 - loss=-1.022 - max pert=10 - epsit=1
# 245 - success rate=229/249 (91.97%) - avg # queries=56.0 - med # queries=36.0 - loss=-1.022 - max pert=10 - epsit=1
# 246 - success rate=229/249 (91.97%) - avg # queries=56.0 - med # queries=36.0 - loss=-1.022 - max pert=10 - epsit=1
# 247 - success rate=230/249 (92.37%) - avg # queries=56.8 - med # queries=36.0 - loss=-1.023 - max pert=10 - epsit=1
# 248 - success rate=230/249 (92.37%) - avg # queries=56.8 - med # queries=36.0 - loss=-1.023 - max pert=10 - epsit=1
# 249 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.023 - max pert=10 - epsit=1
# 250 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.023 - max pert=10 - epsit=1
# 251 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.023 - max pert=10 - epsit=1
# 252 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.023 - max pert=10 - epsit=1
# 253 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.023 - max pert=10 - epsit=1
# 254 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.023 - max pert=10 - epsit=1
# 255 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.023 - max pert=10 - epsit=1
# 256 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.024 - max pert=10 - epsit=1
# 257 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.024 - max pert=10 - epsit=1
# 258 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.024 - max pert=10 - epsit=1
# 259 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.024 - max pert=10 - epsit=1
# 260 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.024 - max pert=10 - epsit=1
# 261 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.024 - max pert=10 - epsit=1
# 262 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.024 - max pert=10 - epsit=1
# 263 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.024 - max pert=10 - epsit=1
# 264 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.024 - max pert=10 - epsit=1
# 265 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.024 - max pert=10 - epsit=1
# 266 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.024 - max pert=10 - epsit=1
# 267 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.024 - max pert=10 - epsit=1
# 268 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.025 - max pert=10 - epsit=1
# 269 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.025 - max pert=10 - epsit=1
# 270 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.025 - max pert=10 - epsit=1
# 271 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.025 - max pert=10 - epsit=1
# 272 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.025 - max pert=10 - epsit=1
# 273 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.025 - max pert=10 - epsit=1
# 274 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.025 - max pert=10 - epsit=1
# 275 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.025 - max pert=10 - epsit=1
# 276 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.025 - max pert=10 - epsit=1
# 277 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.025 - max pert=10 - epsit=1
# 278 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.025 - max pert=10 - epsit=1
# 279 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.025 - max pert=10 - epsit=1
# 280 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.025 - max pert=10 - epsit=1
# 281 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.025 - max pert=10 - epsit=1
# 282 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.025 - max pert=10 - epsit=1
# 283 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 284 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 285 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 286 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 287 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 288 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 289 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 290 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 291 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 292 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 293 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 294 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 295 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 296 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 297 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 298 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 299 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 300 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 301 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 302 - success rate=231/249 (92.77%) - avg # queries=57.6 - med # queries=37.0 - loss=-1.026 - max pert=10 - epsit=1
# 303 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 304 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 305 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 306 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 307 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 308 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 309 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 310 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 311 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 312 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 313 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 314 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 315 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 316 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 317 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 318 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.027 - max pert=10 - epsit=1
# 319 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 320 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 321 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 322 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 323 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 324 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 325 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 326 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 327 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 328 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 329 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 330 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 331 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 332 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 333 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 334 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 335 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 336 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 337 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.028 - max pert=10 - epsit=1
# 338 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.029 - max pert=10 - epsit=1
# 339 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.029 - max pert=10 - epsit=1
# 340 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.029 - max pert=10 - epsit=1
# 341 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.029 - max pert=10 - epsit=1
# 342 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.029 - max pert=10 - epsit=1
# 343 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.029 - max pert=10 - epsit=1
# 344 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.029 - max pert=10 - epsit=1
# 345 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.029 - max pert=10 - epsit=1
# 346 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.029 - max pert=10 - epsit=1
# 347 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.029 - max pert=10 - epsit=1
# 348 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.029 - max pert=10 - epsit=1
# 349 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.029 - max pert=10 - epsit=1
# 350 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.029 - max pert=10 - epsit=1
# 351 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 352 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 353 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 354 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 355 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 356 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 357 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 358 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 359 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 360 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 361 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 362 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 363 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 364 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 365 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 366 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 367 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 368 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 369 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 370 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.030 - max pert=10 - epsit=1
# 371 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.031 - max pert=10 - epsit=1
# 372 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.031 - max pert=10 - epsit=1
# 373 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.031 - max pert=10 - epsit=1
# 374 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.031 - max pert=10 - epsit=1
# 375 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.031 - max pert=10 - epsit=1
# 376 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.031 - max pert=10 - epsit=1
# 377 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.031 - max pert=10 - epsit=1
# 378 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.031 - max pert=10 - epsit=1
# 379 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.031 - max pert=10 - epsit=1
# 380 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.031 - max pert=10 - epsit=1
# 381 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.031 - max pert=10 - epsit=1
# 382 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.031 - max pert=10 - epsit=1
# 383 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.032 - max pert=10 - epsit=1
# 384 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.032 - max pert=10 - epsit=1
# 385 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.032 - max pert=10 - epsit=1
# 386 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.032 - max pert=10 - epsit=1
# 387 - success rate=232/249 (93.17%) - avg # queries=58.7 - med # queries=37.0 - loss=-1.032 - max pert=10 - epsit=1
# 388 - success rate=233/249 (93.57%) - avg # queries=60.1 - med # queries=37.0 - loss=-1.032 - max pert=10 - epsit=1
# 389 - success rate=233/249 (93.57%) - avg # queries=60.1 - med # queries=37.0 - loss=-1.032 - max pert=10 - epsit=1
# 390 - success rate=233/249 (93.57%) - avg # queries=60.1 - med # queries=37.0 - loss=-1.032 - max pert=10 - epsit=1
# 391 - success rate=234/249 (93.98%) - avg # queries=61.5 - med # queries=37.0 - loss=-1.033 - max pert=10 - epsit=1
# 392 - success rate=234/249 (93.98%) - avg # queries=61.5 - med # queries=37.0 - loss=-1.034 - max pert=10 - epsit=1
# 393 - success rate=234/249 (93.98%) - avg # queries=61.5 - med # queries=37.0 - loss=-1.034 - max pert=10 - epsit=1
# 394 - success rate=234/249 (93.98%) - avg # queries=61.5 - med # queries=37.0 - loss=-1.034 - max pert=10 - epsit=1
# 395 - success rate=234/249 (93.98%) - avg # queries=61.5 - med # queries=37.0 - loss=-1.034 - max pert=10 - epsit=1
# 396 - success rate=235/249 (94.38%) - avg # queries=62.9 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 397 - success rate=235/249 (94.38%) - avg # queries=62.9 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 398 - success rate=235/249 (94.38%) - avg # queries=62.9 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 399 - success rate=235/249 (94.38%) - avg # queries=62.9 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 400 - success rate=235/249 (94.38%) - avg # queries=62.9 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 401 - success rate=235/249 (94.38%) - avg # queries=62.9 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 402 - success rate=235/249 (94.38%) - avg # queries=62.9 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 403 - success rate=235/249 (94.38%) - avg # queries=62.9 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 404 - success rate=236/249 (94.78%) - avg # queries=64.4 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 405 - success rate=236/249 (94.78%) - avg # queries=64.4 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 406 - success rate=236/249 (94.78%) - avg # queries=64.4 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 407 - success rate=236/249 (94.78%) - avg # queries=64.4 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 408 - success rate=236/249 (94.78%) - avg # queries=64.4 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 409 - success rate=236/249 (94.78%) - avg # queries=64.4 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 410 - success rate=236/249 (94.78%) - avg # queries=64.4 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 411 - success rate=236/249 (94.78%) - avg # queries=64.4 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 412 - success rate=236/249 (94.78%) - avg # queries=64.4 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 413 - success rate=236/249 (94.78%) - avg # queries=64.4 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 414 - success rate=236/249 (94.78%) - avg # queries=64.4 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 415 - success rate=236/249 (94.78%) - avg # queries=64.4 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# 416 - success rate=236/249 (94.78%) - avg # queries=64.4 - med # queries=38.0 - loss=-1.035 - max pert=10 - epsit=1
# ...
# 565 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 566 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 567 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 568 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 569 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 570 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 571 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 572 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 573 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 574 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 575 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 576 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 577 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 578 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 579 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 580 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 581 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 582 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 583 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 584 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 585 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 586 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 587 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 588 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 589 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 590 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 591 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 592 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 593 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 594 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 595 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 596 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 597 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 598 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 599 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 600 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 601 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 602 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 603 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 604 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 605 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 606 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 607 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 608 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 609 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 610 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 611 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 612 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 613 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 614 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 615 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 616 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 617 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 618 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 619 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 620 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 621 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 622 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 623 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 624 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 625 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 626 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 627 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 628 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 629 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 630 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 631 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 632 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 633 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 634 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 635 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 636 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 637 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 638 - success rate=240/249 (96.39%) - avg # queries=71.0 - med # queries=39.0 - loss=-1.045 - max pert=10 - epsit=1
# 639 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 640 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 641 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 642 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 643 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 644 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 645 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 646 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 647 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 648 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 649 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 650 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 651 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 652 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 653 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 654 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 655 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 656 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 657 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 658 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 659 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 660 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 661 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 662 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 663 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 664 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 665 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 666 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 667 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 668 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 669 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 670 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 671 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 672 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 673 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 674 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 675 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 676 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 677 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 678 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 679 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 680 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 681 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 682 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 683 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 684 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 685 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 686 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 687 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 688 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 689 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 690 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 691 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 692 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 693 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 694 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 695 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 696 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 697 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 698 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 699 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# 700 - success rate=241/249 (96.79%) - avg # queries=73.4 - med # queries=39.0 - loss=-1.046 - max pert=10 - epsit=1
# restart 0 - robust accuracy: 3.12% - cum. time: 6.7 s
# CPU times: user 24 s, sys: 58.6 ms, total: 24 s
# Wall time: 6.7 s

# %%
advs = adv_examples.cpu()

pred0 = net(data[0].to(device))
pred0 = pred0.argmax(axis=1)

pred1 = net(adv_examples)
pred1 = pred1.argmax(axis=1)

# %%
import matplotlib.pyplot as plt

n = 6
fig, axs = plt.subplots(
   nrows=n, ncols=n, sharex=True, sharey=True, figsize=(12, 12))

for i in range(n ** 2 // 2):

    ax = axs[(i * 2) // n, (i * 2) % n]
    ax.imshow(data[0][i].squeeze(), cmap=plt.cm.gray)
    ax.set_title(f'label:{data[1][i]}, pred:{pred0[i]}')
    ax.axis('off')

    ax = axs[(i * 2 + 1) // n, (i * 2 + 1) % n]
    ax.imshow(advs[i].squeeze(), cmap=plt.cm.gray)
    ax.set_title(f'label:{data[1][i]}, pred:{pred1[i]}')
    ax.axis('off')

plt.tight_layout()
plt.show()
